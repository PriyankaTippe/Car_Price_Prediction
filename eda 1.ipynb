# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv("new_cleaned_data.csv")
ds
# Out:
#      Unnamed: 0   company                            name  year  kms_driven  \
# 0             0   Hyundai    Santro Xing XO eRLX Euro III  2007       45000
# 1             1   Hyundai  Grand i10 Magna 1.2 Kappa VTVT  2014       28000
# 2             2      Ford     EcoSport Titanium 1.5L TDCi  2014       36000
# 3             3      Ford                            Figo  2012       41000
# 4             4   Hyundai                             Eon  2013       25000
# ..          ...       ...                             ...   ...         ...
# 646         646    Maruti             Suzuki Ritz VXI ABS  2011       50000
# 647         647      Tata            Indica V2 DLE BS III  2009       30000
# 648         648    Toyota                   Corolla Altis  2009      132000
# 649         649      Tata                  Zest XM Diesel  2018       27000
# 650         650  Mahindra                       Quanto C8  2013       40000
#
#     fuel_type     Price
# 0      Petrol   80000.0
# ...

# %%
ds.reset_index(inplace=True)

# %%
ds[["company","name","year","kms_driven","fuel_type","Price"]].to_csv("new_cleaned_data.csv")

# %%
#barplot

companywisecount=ds.groupby("company")["company"].count()
plt.figure(figsize=(15,5))
ax=companywisecount.plot(kind='bar',color='purple',title='company-wise count')
plt.xticks(rotation=45)
for i,v in enumerate(companywisecount):
    ax.text(i,v+0.1,str(v),ha='center',va='bottom')
plt.xlabel=('company')
plt.ylabel=('count')
plt.show()

# %%
# count of cars by year in barplot

vehicle_count=ds["year"].value_counts().sort_index()
plt.figure(figsize=(15,6))
vehicle_count.plot(kind='bar',color='blue')
plt.title('count of car by year')
plt.xticks(rotation=45)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()

# %%
# pie chart


def autopct_with_count(pct,all_vals):
    absolute=int(round(pct/100.*sum(all_vals)))
    return f"{absolute}\n({pct:.1f}%)"
fuel_count=ds["fuel_type"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(fuel_count.values,labels=fuel_count.index, autopct=lambda pct:autopct_with_count(pct,fuel_count.values),startangle=0,colors=plt.cm.Paired.colors)
plt.title('Proportion of cars by fuel type')
plt.tight_layout()
plt.show()

# %%
# swarm plot        (It shows concentration of price for rach fuel type,  outlier shows high price of car)

plt.figure(figsize=(10,6))
sns.swarmplot(x='fuel_type',y='Price',data=ds,palette='Paired')
plt.title('Cars Prices by Fuel Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_19336\512508495.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='fuel_type',y='Price',data=ds,palette='Paired')
# C:\Users\priya\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 47.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\priya\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 26.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\priya\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 46.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
# histogram for Price,year,kms_driven       (It shows how a numerical variables distributed)

plt.figure(figsize=(8,3))
plt.hist(ds['Price'],bins=20,color='purple',edgecolor='black')
plt.title('Distribution of car Prices')
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,3))
plt.hist(ds['year'],bins=len(ds['year'].unique()),color='lightgreen',edgecolor='black')
plt.title('Distribution of car manufacturing years')
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,3))
plt.hist(ds['kms_driven'],bins=20,color='salmon',edgecolor='black')
plt.title('Distribution of kms_driven')
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.tight_layout()
plt.show()
